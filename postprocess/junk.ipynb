# %% [markdown]
# # import libraries

# %%
#--- system libraries


#--- user modules
#from utility import *
import utility as utl

#--- figure settings
#matplotlib.rcParams['text.usetex'] = True #--- comment tex stuff!

# %%
utl.PltErr([1,2],[2,3],xstr=r'$x$')
# Out:
# <AxesSubplot:xlabel='$x$'>
